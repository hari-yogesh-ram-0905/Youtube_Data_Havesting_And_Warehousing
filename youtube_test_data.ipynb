# %%
#                                                  step - 1 :  [ Import the googleapiclient ]

from googleapiclient.discovery import build

import googleapiclient.errors

#import pprint

# %% [markdown]
# #  How to generate the "requirements.txt
#
# ###  pip freeze > requirements.txt

# %%
#                                                  Step - 2 : [ API KEY CONNECTIONS ]

# We can collect API_KEY [from Google Developer Console] 

# And now we can  give "API  CONNECTIONS

# Write 'Functions' for "Api  Connections"

def Api_connections(API_KEY):                        

    # We can refer this link and collect the python code whatever we needed : https://developers.google.com/youtube/v3/docs/channels/list?apix=true
    
    # Api_Key = "AIzaSyDTnfWSKSLBxDrvbaWgbYU3OmEJ1XON5As"

    Api_Key = API_KEY

    api_service_name = "youtube"

    api_version = "v3"

    # build() , inside the build methods, we can pass the parameters

    # youtube = build(api_service_name, api_version, Api_Key)

    youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey = Api_Key)

    return youtube



youtube = Api_connections("AIzaSyBxcK5jsK2ntHWEviOWuQ_EIaIGDY4DZxA")      # Give your API KEY here

# %%
# print(youtube)

youtube

# %%
#                                                    STEP - 3 : [ Get Channels Information]  
#               
import pandas as pd              

# USING FOR LOOP [get any particular data from response [by using keys]]

# create a function to pass the channel id aand get channels details

def get_channels_info(channel_id):

    # Get Channels informations

    # inside the list() => pass the parameters 
    request = youtube.channels().list(
    
      # pass parameters : snippet , ContentDetails and statistics 
      
      part = "snippet, ContentDetails, statistics",

      # give youtube channel Id
      
      #id = "UCJcCB-QYPIBcbKcBQOTwhiA"    (VJ SIDDHU VLOGS)
      
      id = channel_id
    )

    response = request.execute()

    channel_data = []
    
    for i in response['items']:
    
      # create a variable and get the particular data based on needs and store it to the variable in dictionary format.
    
      get_data_from_response = dict(Channel_Name = i['snippet']['title'],
                                    Channel_Id = i['id'],
                                    Subscription_Count = i['statistics']['subscriberCount'],
                                    Channel_Views = i['statistics']['viewCount'],
                                    Channel_Description = i['snippet']['description'], # this channel has no description.so 'null'
                                    Playlist_Id = i['contentDetails']['relatedPlaylists']['uploads'] # ~= uploads
                              )
    
      channel_data.append(get_data_from_response)
    
    channel_data_df = pd.DataFrame(channel_data)

    return channel_data_df

# Get_channel_Details = get_channels_info("UCMyiKJ5PO2TIJhQkZqgpffw")    # give any 'channel_id' to get the  channel details 

Get_channel_Details = get_channels_info("UCJcCB-QYPIBcbKcBQOTwhiA")    # give any channel id 

Get_channel_Details
# Out:
#       Channel_Name                Channel_Id Subscription_Count Channel_Views  \
# 0  Vj Siddhu Vlogs  UCJcCB-QYPIBcbKcBQOTwhiA            5050000    1400271076
#
#                                  Channel_Description               Playlist_Id
# 0  Hello guys! Welcome to my channel! !\n\nMy cha...  UUJcCB-QYPIBcbKcBQOTwhiA

# %%
#                                                    STEP - 4 [Get Video ID'S]

Video_Ids = []    # Here , we can store the 'total number of video Ids' [present in the given Youtube Channel_ID's]



# [by passing the channel_ids in the list ]  = > we get 'playlist_id'

# Next , From the  playlist_Id (nothing but 'uploads_id')  => To Get the "Videos_Id"


get_playlist_id = youtube.channels().list(id = "UCJcCB-QYPIBcbKcBQOTwhiA",
                                          part = "contentDetails").execute()

# Now , I am going to get  'playlist_Id' == ['upload_video_id]

Playlist_Id = get_playlist_id['items'][0]['contentDetails']['relatedPlaylists']['uploads']

# %%
Playlist_Id
# Out:
# 'UUJcCB-QYPIBcbKcBQOTwhiA'

# %%
# Now , use this playlist_id  =>  to collect the Videos_id

# Refer this API :        'PlaylistItems' -->                                link : https://developers.google.com/youtube/v3/docs/playlistItems/list

# %%
get_video_id = youtube.playlistItems().list(
        part="snippet",
        playlistId="UUJcCB-QYPIBcbKcBQOTwhiA"

    ).execute()

# %%
get_video_id
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': 'ZzlOIN4lnB5faFShipTLbgQissg',
#  'nextPageToken': 'EAAaHlBUOkNBVWlFRE5DTkRjNVF6VkRSRVF3TkRJNVJqTQ',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': '8UBNiHmKhaPOPbC7hnoDl5YFHeQ',
#    'id': 'VVVKY0NCLVFZUElCY2JLY0JRT1R3aGlBLnRacGc5ZVZnOXFV',
#    'snippet': {'publishedAt': '2025-08-17T04:30:07Z',
#     'channelId': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#     'title': 'இதுக்கு மேல செல்லத்த பாக்க முடியாது😢🥹 | Car Series | Ep - 07 | Vj Siddhu Vlogs',
# ...

# %%
# Now , I want to get the video id at position 0

get_video_id['items'][0]['snippet']['resourceId']['videoId']               # position 0 => videoId
# Out:
# 'tZpg9eVg9qU'

# %%
# Now , I can collect "50 videoIds"(reults per page) using For loop

len(get_video_id['items'])
# Out:
# 5

# %%
# Here , I need list of video Ids

videoId = []

for i in range(len(get_video_id['items'])):

  videoId.append(get_video_id['items'][i]['snippet']['resourceId']['videoId'])
  

# Now print the "Video_Ids" list 

videoId             # Here, I got list of 50 'video Ids'
# Out:
# ['tZpg9eVg9qU', 'XrLxZWNGj04', 'PI9m0jIAJkY', 'zavhAY_mmnw', 'iiFeTSSDay4']

# %%
# Length (List of Videos Id)

len(videoId)
# Out:
# 5

# %%
# Here I got only 50 'VideoId'

# But , In this Channel Id , there are 369 videos are there .

# So , I want to get all 369 videos.

# Here , we have to proceed on it to get "369 videoIds"

# %%
get_video_id
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': 'ZzlOIN4lnB5faFShipTLbgQissg',
#  'nextPageToken': 'EAAaHlBUOkNBVWlFRE5DTkRjNVF6VkRSRVF3TkRJNVJqTQ',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': '8UBNiHmKhaPOPbC7hnoDl5YFHeQ',
#    'id': 'VVVKY0NCLVFZUElCY2JLY0JRT1R3aGlBLnRacGc5ZVZnOXFV',
#    'snippet': {'publishedAt': '2025-08-17T04:30:07Z',
#     'channelId': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#     'title': 'இதுக்கு மேல செல்லத்த பாக்க முடியாது😢🥹 | Car Series | Ep - 07 | Vj Siddhu Vlogs',
# ...

# %%
Video_Ids = []

# After getting the 50 videoId's

# # Using 'nextPageToken' from 'get_video_id' = > to collect that "full video Id's"

next_page_token = None

# And Also add the parameters called 'pageToken'  [inside the list]
  
while True: 

    get_video_id = youtube.playlistItems().list(
            part="snippet",
            maxResults=50,
            playlistId="UUJcCB-QYPIBcbKcBQOTwhiA",

            # 'pageToken'  [inside the list] => to collect "all videoIds"

            pageToken = next_page_token          # passing the variable [next_page_token] from 'get_video_id' 


        ).execute()

    for i in range(len(get_video_id['items'])):

        Video_Ids.append(get_video_id['items'][i]['snippet']['resourceId']['videoId'])       
        
    next_page_token = get_video_id.get('nextPageToken')


    if next_page_token is None:

        break


# get list of video_id's

Video_Ids
# Out:
# ['tZpg9eVg9qU',
#  'XrLxZWNGj04',
#  'PI9m0jIAJkY',
#  'zavhAY_mmnw',
#  'iiFeTSSDay4',
#  'hfzo5nvkiEM',
#  'Gjv3jItyEuA',
#  'nXgF4zA4oNs',
#  'q2kiw19EWOk',
#  'OHL1wjAqYPo',
#  'JPf-7pMEJAM',
#  'u6kQOZDpcvs',
#  'kWJs1aVU3hA',
#  'K9LQQIA-D9M',
#  'Rwl6604OF7o',
#  'PIzqLXUR2xw',
#  'cKbeJx3xpgc',
#  'Gen__j6J_x8',
#  'yyCsu3O4f1E',
#  'wtlKyhY1vWs',
#  '40RXHPxgQ1w',
#  '1qq_3fEZ1pc',
#  'xb8CGOfKSIw',
#  '41lgW1YuUyI',
#  '1Ldqo7TpaMw',
#  'W1FXd-JCXBs',
#  'uPEMBwt1AkI',
#  'RW9JvKTjoY8',
#  'bTS_Vj5cUXQ',
#  'KNSyz7eX3eI',
#  'JyvCpn8hE4I',
#  'ehD304boTLY',
#  'VUBmvOHGre8',
#  'Et15x3Gvw0E',
#  'TrJq39uhFEw',
#  'FAeP6-_0jTQ',
#  'NR5wFN0U1hU',
#  'lC-Bdpdw7VM',
#  'RtZaUf0TZ4M',
#  'D_yuW5wZ2Jk',
#  '6e_qFqrWCJ0',
#  'gsUfXFfa1Zo',
#  'wiH7lg3LxZM',
#  'VxJq7ZkGgPc',
#  's3Ci3qj7-_w',
#  'Rk72E1wGRvA',
#  '5c6_J24cYqY',
#  'UpYOrdGWWtQ',
#  'lmHOYfJI1ZA',
#  'QYjkbaPsngA',
#  'PMbaMUWvrIw',
#  'VcC9P9Pncz4',
#  'u6GfIjM-PCY',
#  '_fSgUNXDq78',
#  '7XF1mZHJtQs',
# ...

# %%
# Length of list of video Ids

print(len(Video_Ids))
# Out:
# 430

# %%
#                                  Step 4 : [ Get all videos  [Using function] => give channel Id as argument to collect all video Ids ]

#get video ids

def get_all_video_ids(channel_id):

    video_ids = []

    get_playlist_id = youtube.channels().list(id=channel_id,
                                    part='contentDetails').execute()

    Playlist_Id = get_playlist_id['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page_token = None

    while True:

        get_video_id = youtube.playlistItems().list(
                                            part='snippet',
                                            playlistId=Playlist_Id,
                                            maxResults=50,
                                            pageToken=next_page_token).execute()

        for i in range(len(get_video_id['items'])):

            video_ids.append(get_video_id['items'][i]['snippet']['resourceId']['videoId'])

        next_page_token = get_video_id.get('nextPageToken')

        if next_page_token is None:

            break
            
    return video_ids

# %%
# Calling the get_all_video_ids Function ....to return the video_ids

videoIDs = get_all_video_ids("UCJcCB-QYPIBcbKcBQOTwhiA")   # give any channel ID

videoIDs
# Out:
# ['tZpg9eVg9qU',
#  'XrLxZWNGj04',
#  'PI9m0jIAJkY',
#  'zavhAY_mmnw',
#  'iiFeTSSDay4',
#  'hfzo5nvkiEM',
#  'Gjv3jItyEuA',
#  'nXgF4zA4oNs',
#  'q2kiw19EWOk',
#  'OHL1wjAqYPo',
#  'JPf-7pMEJAM',
#  'u6kQOZDpcvs',
#  'kWJs1aVU3hA',
#  'K9LQQIA-D9M',
#  'Rwl6604OF7o',
#  'PIzqLXUR2xw',
#  'cKbeJx3xpgc',
#  'Gen__j6J_x8',
#  'yyCsu3O4f1E',
#  'wtlKyhY1vWs',
#  '40RXHPxgQ1w',
#  '1qq_3fEZ1pc',
#  'xb8CGOfKSIw',
#  '41lgW1YuUyI',
#  '1Ldqo7TpaMw',
#  'W1FXd-JCXBs',
#  'uPEMBwt1AkI',
#  'RW9JvKTjoY8',
#  'bTS_Vj5cUXQ',
#  'KNSyz7eX3eI',
#  'JyvCpn8hE4I',
#  'ehD304boTLY',
#  'VUBmvOHGre8',
#  'Et15x3Gvw0E',
#  'TrJq39uhFEw',
#  'FAeP6-_0jTQ',
#  'NR5wFN0U1hU',
#  'lC-Bdpdw7VM',
#  'RtZaUf0TZ4M',
#  'D_yuW5wZ2Jk',
#  '6e_qFqrWCJ0',
#  'gsUfXFfa1Zo',
#  'wiH7lg3LxZM',
#  'VxJq7ZkGgPc',
#  's3Ci3qj7-_w',
#  'Rk72E1wGRvA',
#  '5c6_J24cYqY',
#  'UpYOrdGWWtQ',
#  'lmHOYfJI1ZA',
#  'QYjkbaPsngA',
#  'PMbaMUWvrIw',
#  'VcC9P9Pncz4',
#  'u6GfIjM-PCY',
#  '_fSgUNXDq78',
#  '7XF1mZHJtQs',
# ...

# %%
# Check how many video_id's are there in this channel?

print(len(videoIDs))
# Out:
# 430

# %%
import pandas as pd

# Convert list of "video IDs" [into a DataFrame]

videoIDs_df = pd.DataFrame(videoIDs)

# Display the video_ID in the DataFrame 

videoIDs_df
# Out:
#                0
# 0    tZpg9eVg9qU
# 1    XrLxZWNGj04
# 2    PI9m0jIAJkY
# 3    zavhAY_mmnw
# 4    iiFeTSSDay4
# ..           ...
# 425  FBZFmBcm-lw
# 426  7f8GkhCakxs
# 427  N6hC1j2p8HI
# 428  2KtPwmjqtBk
# 429  OkuCdKIYzX0
#
# [430 rows x 1 columns]

# %%
#                                                   Step - 5 : [ Get Video informations ]

for video_id in videoIDs:       

  # get youtube [video information ] , collect from this link :           https://developers.google.com/youtube/v3/docs/videos/list?apix=true
  
  get_video_info = youtube.videos().list(
      
        part = "snippet,ContentDetails,statistics",
        id = video_id
    )
  
  response = get_video_info.execute()

# %%
# Now, check the response of the "video_information"

response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'wcyfcptjB5sXyucSBSewLUXNf38',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'iDIg1XQzCIKXO-l7uVZJGi45B4o',
#    'id': 'OkuCdKIYzX0',
#    'snippet': {'publishedAt': '2023-06-17T11:02:30Z',
#     'channelId': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#     'title': 'நான் வந்துட்டேன் சொல்லு திரும்ப வந்துட்டேனு சொல்லு..! | New Channel | Vj Siddhu Vlogs',
#     'description': 'For inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n  #VjSiddhuVlogs #VjSiddhu #SidhhuVlogs\n\n\nWelcome to Vj Sidhhu Vlogs. \nSubscribe at https://youtube.com/@VjSiddhuVlog',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OkuCdKIYzX0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/OkuCdKIYzX0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/OkuCdKIYzX0/hqdefault.jpg',
#       'width': 480,
# ...

# %%
response['items'][0]['contentDetails']['caption']      # we get the video details individually
# Out:
# 'false'

# %%
# Using for loop , we can collect video information based on user need's

# need to print the output in Dataframe format

# import pandas as pd


def get_videos_details(videoIDs):

  video_details = []                  # to store 'all videos_info' in the list

  for i in response['items']:

    video_Data = dict(Video_Id = i['id'],
                Video_Name = i['snippet']['title'],
                Video_Description = i['snippet']['description'],
                Tags = i['snippet']['tags'],
                PublishedAt = i['snippet']['publishedAt'],
                View_Count = i['statistics']['viewCount'],
                Like_Count = i['statistics']['likeCount'],
                # Dislike_Count = i['statistics']['dislikeCount'] ,
                Favorite_Count = i['statistics']['favoriteCount'] ,
                Comment_Count = i['statistics']['commentCount'],
                Duration = i['contentDetails']['duration'],
                Thumbnail = i['snippet']['thumbnails'],
                Caption_Status = i['contentDetails']['caption']
                )

    video_details.append(video_Data)

  return video_details


videos_info_results = get_videos_details("PKUCLg6xOeY")      # give the video IDs here

videos_info_results 


# Results in DATAFRAME format

# videos_info_results_df = pd.Dataframe(videos_info_results)

# print(videos_info_results_df)
# Out:
# [{'Video_Id': 'OkuCdKIYzX0',
#   'Video_Name': 'நான் வந்துட்டேன் சொல்லு திரும்ப வந்துட்டேனு சொல்லு..! | New Channel | Vj Siddhu Vlogs',
#   'Video_Description': 'For inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n  #VjSiddhuVlogs #VjSiddhu #SidhhuVlogs\n\n\nWelcome to Vj Sidhhu Vlogs. \nSubscribe at https://youtube.com/@VjSiddhuVlog',
#   'Tags': ['Vj siddhu vlogs',
#    'Vj siddhu',
#    'sidhhu vlogs',
#    'vj siddhu new channel',
#    'siddhu new vlog',
#    'vj siddhu vlogs',
#    'blacksheep sidhhu vlogs',
#    'fun pandrom vlogs',
#    'fun panrom vlogs',
#    'vj sidhhu new vlog',
#    'vj siddhu channel',
#    'Siddhu new channel'],
#   'PublishedAt': '2023-06-17T11:02:30Z',
#   'View_Count': '1148976',
#   'Like_Count': '88319',
#   'Favorite_Count': '0',
#   'Comment_Count': '550',
#   'Duration': 'PT1M5S',
#   'Thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/OkuCdKIYzX0/default.jpg',
#     'width': 120,
#     'height': 90},
# ...

# %%
import pandas as pd 

videos_info_results_df = pd.DataFrame(videos_info_results)

videos_info_results_df
# Out:
#       Video_Id                                         Video_Name  \
# 0  OkuCdKIYzX0  நான் வந்துட்டேன் சொல்லு திரும்ப வந்துட்டேனு சொ...
#
#                                    Video_Description  \
# 0  For inquiries please contact us :7200571056\nG...
#
#                                                 Tags           PublishedAt  \
# 0  [Vj siddhu vlogs, Vj siddhu, sidhhu vlogs, vj ...  2023-06-17T11:02:30Z
#
#   View_Count Like_Count Favorite_Count Comment_Count Duration  \
# 0    1148976      88319              0           550   PT1M5S
#
#                                            Thumbnail Caption_Status
# 0  {'default': {'url': 'https://i.ytimg.com/vi/Ok...          false

# %%
# step : 6 [Get comment details]

# for video_id in videoIDs:

# Reference link :  https://developers.google.com/youtube/v3/docs/commentThreads/list?apix=true

request=youtube.commentThreads().list(  

    part = "snippet",  
    videoId = video_id,
    maxResults = 50
)

response = request.execute()

# %%
response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': '1OU0lE6cJSHPjBkGugQWplfNF1Y',
#  'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJY2dHQUFTQlFpb0lCZ0FFZ1VJblNBWUFSSUZDSWdnR0FBU0JRaUpJQmdBSWc0S0RBaS0xNVdfQmhDbzFOZVFBdw==',
#  'pageInfo': {'totalResults': 50, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'Mwxpo3CF-QNj4sRZhEwci5Xjeto',
#    'id': 'UgxZoVtd9M4Xs7fVDi94AaABAg',
#    'snippet': {'channelId': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#     'videoId': 'OkuCdKIYzX0',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'm7kwSf_6obtqJwjlt97Ti8mmfUk',
#      'id': 'UgxZoVtd9M4Xs7fVDi94AaABAg',
#      'snippet': {'channelId': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#       'videoId': 'OkuCdKIYzX0',
#       'textDisplay': 'Hlo bro I am manijunan❤',
#       'textOriginal': 'Hlo bro I am manijunan❤',
#       'authorDisplayName': '@LaxmanChaupal-j4l',
# ...

# %%
#                                                   get 'comment details' [ one by one ]



# response['items'][0]['snippet']['topLevelComment']['id']                                      #   => get Comment Id

# response['items'][0]['snippet']['topLevelComment']['snippet']['videoId']                      #   => get videoId

# response['items'][0]['snippet']['topLevelComment']['snippet']['textDisplay']                  #   => get comment text

# response['items'][0]['snippet']['topLevelComment']['snippet']['authorDisplayName']            #   => get comment Author

response['items'][0]['snippet']['topLevelComment']['snippet']['publishedAt']                    #  => get comment published date
# Out:
# '2025-08-15T02:10:23Z'

# %%
comment_data = []

for i in response['items']:

    data=dict(Comment_Id=i['snippet']['topLevelComment']['id'],
                        Video_Id=i['snippet']['topLevelComment']['snippet']['videoId'],
                        Comment_Text=i['snippet']['topLevelComment']['snippet']['textDisplay'],
                        Comment_Author=i['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                        Comment_Published=i['snippet']['topLevelComment']['snippet']['publishedAt'])
                
    comment_data.append(data)

# %%
#                                                        STEP - 6 : [Get Comment Details]

#  get comment information  by passing 'videoIDs'

import pandas as pd

def get_comment_details(videoIDs):

    Comment_data = []

    try:

        for video_id in Video_Ids:

            # Reference link :  https://developers.google.com/youtube/v3/docs/commentThreads/list?apix=true

            request=youtube.commentThreads().list(  

                part = "snippet",  
                videoId = video_id,
                maxResults = 50
            )

            response = request.execute()

            for i in response['items']:

                data = dict(Comment_Id = i['snippet']['topLevelComment']['id'],
                            Video_Id = i['snippet']['topLevelComment']['snippet']['videoId'],
                            Comment_Text = i['snippet']['topLevelComment']['snippet']['textDisplay'],
                            Comment_Author = i['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                            Comment_Published = i['snippet']['topLevelComment']['snippet']['publishedAt'])
                
                Comment_data.append(data)
                
    except:

        pass
    
    return Comment_data


# display comment details by calling the function and passing the videoIDs

comment_details = get_comment_details("PKUCLg6xOeY")     # videoIDs 

comment_details


# need ouput in the Dataframe

comment_details_df = pd.DataFrame(comment_details)

comment_details_df
# Out:
#                        Comment_Id     Video_Id  \
# 0      UgwR6z6EcprKB1RYlOF4AaABAg  tZpg9eVg9qU
# 1      UgyQz05qoFCLS37uK454AaABAg  tZpg9eVg9qU
# 2      Ugy1bvq2GYu_UW9L8Zl4AaABAg  tZpg9eVg9qU
# 3      UgzX5b1hO2-p82vyT7N4AaABAg  tZpg9eVg9qU
# 4      UgwGStO2b5u7NTzeaKZ4AaABAg  tZpg9eVg9qU
# ...                           ...          ...
# 20846  Ugz6lFU5xhXWpV9N0514AaABAg  5PN73jENxzA
# 20847  Ugw5c7fxLt7Gc7mxzWx4AaABAg  5PN73jENxzA
# 20848  UgxS-1wYp_zDKYFISlB4AaABAg  5PN73jENxzA
# 20849  UgwVEKVd3HbIk1LxCe54AaABAg  5PN73jENxzA
# 20850  Ugx6ZohSyaXQVHxAAAh4AaABAg  5PN73jENxzA
#
#                                             Comment_Text  \
# 0                                                   😅😅😅😅
# 1      Anna 5 million subscribers vanthutu next yeppo...
# 2      <a href="https://www.youtube.com/watch?v=tZpg9...
# 3                             Motta maadi party epo....🎉
# 4                                    Download apsen pls😢
# ...

# %%
#   7) [Get Playlist Details]

get_playlist_info = youtube.playlists().list(

        part = "snippet,contentDetails",
        channelId = "UCJcCB-QYPIBcbKcBQOTwhiA",     # channel_id (get from 'VJ Siddhu Vlogs' )
        maxResults = 50,
        # pageToken = "next_page_token"
    )


response = get_playlist_info.execute()

# %%
# we can see the result

response
# Out:
# {'kind': 'youtube#playlistListResponse',
#  'etag': 'g3UQiubH6p11ZKBxC6N0hjTxvpg',
#  'pageInfo': {'totalResults': 42, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#playlist',
#    'etag': '1MGal2c125Qc_XWjCZa6vsraqi8',
#    'id': 'PLjnNpn3gLsF81xRsMekTeAeRpZygojpTd',
#    'snippet': {'publishedAt': '2025-08-04T07:39:47.173347Z',
#     'channelId': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#     'title': 'Car Series🚗💨| Vj Siddhu Vlogs',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tZpg9eVg9qU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/tZpg9eVg9qU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/tZpg9eVg9qU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/tZpg9eVg9qU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
# ...

# %%
# we can retrive only 3 data's from the response items :

# playlist_Id 
# channel_id
# playlist_name

# response['items'][0]['id']                             # playlist_id

# response['items'][0]['snippet']['channelId']           # channel_Id

response['items'][0]['snippet']['title']               # playlist_name
# Out:
# 'Car Series🚗💨| Vj Siddhu Vlogs'

# %%
for i in response['items']:
                    
                        playlist_data = dict(Playlist_Id = i['id'],
                                             Channel_Id = i['snippet']['channelId'],
                                             Playlist_Name = i['snippet']['title'],
                                            #  Channel_Name = i['snippet']['channelTitle'],
                                             Video_Count = i['contentDetails']['itemCount'],
                                             PublishedAt = i['snippet']['publishedAt'])
                                             
playlist_data
# Out:
# {'Playlist_Id': 'PLjnNpn3gLsF8v7EdZFvgEq2fAuHdByeEH',
#  'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#  'Playlist_Name': 'Vlogs | Vj Siddhu Vlogs',
#  'Video_Count': 85,
#  'PublishedAt': '2023-06-20T10:24:15.307474Z'}

# %%
#    STEP : 7    [Get Playlist Details]

# By using function : passing the channel Id to return the all_playlist data


def get_playlist_details(channel_id):

        next_page_token = None

        playlist_name = []

        while True:

                #  API REFERENCE LINK :               https://developers.google.com/youtube/v3/docs/playlists/list?apix=true

                request = youtube.playlists().list(

                        part = 'snippet,contentDetails',
                        channelId = channel_id,
                        maxResults = 50,
                        pageToken = next_page_token
                )

                response = request.execute()

                for i in response['items']:
                    
                        playlist_data = dict(Playlist_Id = i['id'],
                                             Channel_Id = i['snippet']['channelId'],
                                             Playlist_Name = i['snippet']['title'],
                                             #  Channel_Name = i['snippet']['channelTitle'],
                                             Video_Count = i['contentDetails']['itemCount'],
                                             PublishedAt = i['snippet']['publishedAt'])

                        playlist_name.append(playlist_data)

                next_page_token=response.get('nextPageToken')

                if next_page_token is None:

                        break
        return playlist_name


# Display the results of  playlist details

playlist_info = get_playlist_details("UCJcCB-QYPIBcbKcBQOTwhiA")    # channel_id for VJ SIDDHU channel

playlist_info
# Out:
# [{'Playlist_Id': 'PLjnNpn3gLsF81xRsMekTeAeRpZygojpTd',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Playlist_Name': 'Car Series🚗💨| Vj Siddhu Vlogs',
#   'Video_Count': 7,
#   'PublishedAt': '2025-08-04T07:39:47.173347Z'},
#  {'Playlist_Id': 'PLjnNpn3gLsF_IMUg58CUTK1E0W1ZLnb6_',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Playlist_Name': 'China Series 🍜🏯 | Vj Siddhu Vlogs',
#   'Video_Count': 17,
#   'PublishedAt': '2025-06-22T04:58:52.681648Z'},
#  {'Playlist_Id': 'PLjnNpn3gLsF_K8NBOK-CmAuZAXHHzkpDP',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Playlist_Name': 'Bachelor Food Series🤩| Vj Siddhu Vlogs',
#   'Video_Count': 6,
#   'PublishedAt': '2025-06-04T10:10:57.864535Z'},
#  {'Playlist_Id': 'PLjnNpn3gLsF8z9bgaZb8_lh1NI7aNxIO4',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Playlist_Name': 'Maldives Series🏝️🌅 | Vj Siddhu Vlogs',
#   'Video_Count': 4,
#   'PublishedAt': '2025-05-23T09:12:59.903664Z'},
#  {'Playlist_Id': 'PLjnNpn3gLsF9YIXRTpwMkFI1fWYiCIaOf',
# ...

# %%
# how many playlists are there in the VJ SDDHU Vlogs channel

len(playlist_info)
# Out:
# 42

# %%
# Now , I will display the results as an Dataframe

import pandas as pd

playlist_info_df = pd.DataFrame(playlist_info)

playlist_info_df
# Out:
#                            Playlist_Id                Channel_Id  \
# 0   PLjnNpn3gLsF81xRsMekTeAeRpZygojpTd  UCJcCB-QYPIBcbKcBQOTwhiA
# 1   PLjnNpn3gLsF_IMUg58CUTK1E0W1ZLnb6_  UCJcCB-QYPIBcbKcBQOTwhiA
# 2   PLjnNpn3gLsF_K8NBOK-CmAuZAXHHzkpDP  UCJcCB-QYPIBcbKcBQOTwhiA
# 3   PLjnNpn3gLsF8z9bgaZb8_lh1NI7aNxIO4  UCJcCB-QYPIBcbKcBQOTwhiA
# 4   PLjnNpn3gLsF9YIXRTpwMkFI1fWYiCIaOf  UCJcCB-QYPIBcbKcBQOTwhiA
# 5   PLjnNpn3gLsF-nMJI0DUFz36UeJNFzK3fC  UCJcCB-QYPIBcbKcBQOTwhiA
# 6   PLjnNpn3gLsF_PTlUj7-8rIiMoiK8TUZzW  UCJcCB-QYPIBcbKcBQOTwhiA
# 7   PLjnNpn3gLsF8Jld33F_aFt2Kdlqg2OcD3  UCJcCB-QYPIBcbKcBQOTwhiA
# 8   PLjnNpn3gLsF82kINVnKDA1IOT1SGF-eW7  UCJcCB-QYPIBcbKcBQOTwhiA
# 9   PLjnNpn3gLsF-4SIBOpwgMOoZUHu-92IW3  UCJcCB-QYPIBcbKcBQOTwhiA
# 10  PLjnNpn3gLsF_MFRVXT0JAf7u-WNNsxwgO  UCJcCB-QYPIBcbKcBQOTwhiA
# 11  PLjnNpn3gLsF-nHqeNF93wMnMZ_wQc8tXn  UCJcCB-QYPIBcbKcBQOTwhiA
# 12  PLjnNpn3gLsF_TPQih1h-qCij0HdpB09xD  UCJcCB-QYPIBcbKcBQOTwhiA
# ...
